# %% [markdown]
# ![Notebook_Header_01.png](data:image/png;base64,...)

# %% [markdown]
# # Lab 3: What's next - Sneak Preview of Circuit Kinitting Toolbox

# %% [markdown]
# # Table of Contents
#
# * [Part 1: Circuit Knitting Toolbox](#Part-1:-Circuit-Knitting-Toolbox)
#     * [Exercise 1](#exercise1)
#     * [Exercise 2](#exercise2)

# %% [markdown]
# # Setup

# %% [markdown]
# As always we'll start with the optional installs. You only need to use the Qiskit install and API Token cells if you don't have those saved from a previous lab.

# %%
### Install Qiskit and relevant packages, if needed
### IMPORTANT: Make sure you are using python 3.10 or 3.11 for compatibility of the required packages
# %pip install qiskit[visualization]==1.0.2
# %pip install qiskit-ibm-runtime
# %pip install qiskit-aer
# %pip install qiskit-transpiler-service
# %pip install graphviz
# %pip install circuit-knitting-toolbox
# %pip install qiskit-serverless -U
# %pip install git+https://github.com/qiskit-community/Quantum-Challenge-Grader.git -U
# Out:
# Requirement already satisfied: qiskit[visualization]==1.0.2 in c:\users\jakob\anaconda3\lib\site-packages (1.0.2)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit[visualization]==1.0.2) (2.8.2)
# Requirement already satisfied: typing-extensions in c:\users\jakob\anaconda3\lib\site-packages (from qiskit[visualization]==1.0.2) (4.12.1)
# Requirement already satisfied: numpy<2,>=1.17 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit[visualization]==1.0.2) (1.23.5)
# Requirement already satisfied: symengine>=0.11 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit[visualization]==1.0.2) (0.11.0)
# Requirement already satisfied: dill>=0.3 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit[visualization]==1.0.2) (0.3.6)
# Requirement already satisfied: sympy>=1.3 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit[visualization]==1.0.2) (1.11.1)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit[visualization]==1.0.2) (5.2.0)
# Requirement already satisfied: rustworkx>=0.14.0 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit[visualization]==1.0.2) (0.14.2)
# Requirement already satisfied: scipy>=1.5 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit[visualization]==1.0.2) (1.10.0)
# Requirement already satisfied: matplotlib>=3.3 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit[visualization]==1.0.2) (3.7.0)
# Requirement already satisfied: pydot in c:\users\jakob\anaconda3\lib\site-packages (from qiskit[visualization]==1.0.2) (2.0.0)
# Requirement already satisfied: seaborn>=0.9.0 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit[visualization]==1.0.2) (0.12.2)
# Requirement already satisfied: Pillow>=4.2.1 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit[visualization]==1.0.2) (9.4.0)
# Requirement already satisfied: pylatexenc>=1.4 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit[visualization]==1.0.2) (2.10)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jakob\anaconda3\lib\site-packages (from matplotlib>=3.3->qiskit[visualization]==1.0.2) (4.25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\jakob\anaconda3\lib\site-packages (from matplotlib>=3.3->qiskit[visualization]==1.0.2) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in c:\users\jakob\anaconda3\lib\site-packages (from matplotlib>=3.3->qiskit[visualization]==1.0.2) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\jakob\anaconda3\lib\site-packages (from matplotlib>=3.3->qiskit[visualization]==1.0.2) (22.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\jakob\anaconda3\lib\site-packages (from matplotlib>=3.3->qiskit[visualization]==1.0.2) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jakob\anaconda3\lib\site-packages (from matplotlib>=3.3->qiskit[visualization]==1.0.2) (1.0.5)
# Requirement already satisfied: six>=1.5 in c:\users\jakob\anaconda3\lib\site-packages (from python-dateutil>=2.8.0->qiskit[visualization]==1.0.2) (1.16.0)
# Requirement already satisfied: pandas>=0.25 in c:\users\jakob\anaconda3\lib\site-packages (from seaborn>=0.9.0->qiskit[visualization]==1.0.2) (1.5.3)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in c:\users\jakob\anaconda3\lib\site-packages (from stevedore>=3.0.0->qiskit[visualization]==1.0.2) (6.0.0)
# Requirement already satisfied: mpmath>=0.19 in c:\users\jakob\anaconda3\lib\site-packages (from sympy>=1.3->qiskit[visualization]==1.0.2) (1.2.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jakob\anaconda3\lib\site-packages (from pandas>=0.25->seaborn>=0.9.0->qiskit[visualization]==1.0.2) (2022.7)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: qiskit-ibm-runtime in c:\users\jakob\anaconda3\lib\site-packages (0.23.0)
# Requirement already satisfied: requests>=2.19 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-ibm-runtime) (2.32.2)
# Requirement already satisfied: numpy>=1.13 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-ibm-runtime) (1.23.5)
# Requirement already satisfied: urllib3>=1.21.1 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-ibm-runtime) (2.2.1)
# Requirement already satisfied: qiskit>=1.0.0 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-ibm-runtime) (1.0.2)
# Requirement already satisfied: pydantic in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-ibm-runtime) (2.7.3)
# Requirement already satisfied: websocket-client>=1.5.1 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-ibm-runtime) (1.8.0)
# Requirement already satisfied: ibm-platform-services>=0.22.6 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-ibm-runtime) (0.53.7)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-ibm-runtime) (2.8.2)
# Requirement already satisfied: requests-ntlm>=1.1.0 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-ibm-runtime) (1.2.0)
# Requirement already satisfied: ibm-cloud-sdk-core<4.0.0,>=3.19.2 in c:\users\jakob\anaconda3\lib\site-packages (from ibm-platform-services>=0.22.6->qiskit-ibm-runtime) (3.20.1)
# Requirement already satisfied: six>=1.5 in c:\users\jakob\anaconda3\lib\site-packages (from python-dateutil>=2.8.0->qiskit-ibm-runtime) (1.16.0)
# Requirement already satisfied: dill>=0.3 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit>=1.0.0->qiskit-ibm-runtime) (0.3.6)
# Requirement already satisfied: rustworkx>=0.14.0 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit>=1.0.0->qiskit-ibm-runtime) (0.14.2)
# Requirement already satisfied: typing-extensions in c:\users\jakob\anaconda3\lib\site-packages (from qiskit>=1.0.0->qiskit-ibm-runtime) (4.12.1)
# Requirement already satisfied: scipy>=1.5 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit>=1.0.0->qiskit-ibm-runtime) (1.10.0)
# Requirement already satisfied: symengine>=0.11 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit>=1.0.0->qiskit-ibm-runtime) (0.11.0)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit>=1.0.0->qiskit-ibm-runtime) (5.2.0)
# Requirement already satisfied: sympy>=1.3 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit>=1.0.0->qiskit-ibm-runtime) (1.11.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jakob\anaconda3\lib\site-packages (from requests>=2.19->qiskit-ibm-runtime) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jakob\anaconda3\lib\site-packages (from requests>=2.19->qiskit-ibm-runtime) (2024.6.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jakob\anaconda3\lib\site-packages (from requests>=2.19->qiskit-ibm-runtime) (2.0.4)
# Requirement already satisfied: cryptography>=1.3 in c:\users\jakob\anaconda3\lib\site-packages (from requests-ntlm>=1.1.0->qiskit-ibm-runtime) (39.0.1)
# Requirement already satisfied: pyspnego>=0.1.6 in c:\users\jakob\anaconda3\lib\site-packages (from requests-ntlm>=1.1.0->qiskit-ibm-runtime) (0.10.2)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\jakob\anaconda3\lib\site-packages (from pydantic->qiskit-ibm-runtime) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in c:\users\jakob\anaconda3\lib\site-packages (from pydantic->qiskit-ibm-runtime) (2.18.4)
# Requirement already satisfied: cffi>=1.12 in c:\users\jakob\anaconda3\lib\site-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime) (1.15.1)
# Requirement already satisfied: PyJWT<3.0.0,>=2.8.0 in c:\users\jakob\anaconda3\lib\site-packages (from ibm-cloud-sdk-core<4.0.0,>=3.19.2->ibm-platform-services>=0.22.6->qiskit-ibm-runtime) (2.8.0)
# Requirement already satisfied: sspilib>=0.1.0 in c:\users\jakob\anaconda3\lib\site-packages (from pyspnego>=0.1.6->requests-ntlm>=1.1.0->qiskit-ibm-runtime) (0.1.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in c:\users\jakob\anaconda3\lib\site-packages (from stevedore>=3.0.0->qiskit>=1.0.0->qiskit-ibm-runtime) (6.0.0)
# Requirement already satisfied: mpmath>=0.19 in c:\users\jakob\anaconda3\lib\site-packages (from sympy>=1.3->qiskit>=1.0.0->qiskit-ibm-runtime) (1.2.1)
# Requirement already satisfied: pycparser in c:\users\jakob\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime) (2.21)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: qiskit-aer in c:\users\jakob\anaconda3\lib\site-packages (0.14.2)
# Requirement already satisfied: psutil>=5 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-aer) (5.9.0)
# Requirement already satisfied: numpy>=1.16.3 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-aer) (1.23.5)
# Requirement already satisfied: scipy>=1.0 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-aer) (1.10.0)
# Requirement already satisfied: qiskit>=0.45.2 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-aer) (1.0.2)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit>=0.45.2->qiskit-aer) (2.8.2)
# Requirement already satisfied: typing-extensions in c:\users\jakob\anaconda3\lib\site-packages (from qiskit>=0.45.2->qiskit-aer) (4.12.1)
# Requirement already satisfied: symengine>=0.11 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit>=0.45.2->qiskit-aer) (0.11.0)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit>=0.45.2->qiskit-aer) (5.2.0)
# Requirement already satisfied: sympy>=1.3 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit>=0.45.2->qiskit-aer) (1.11.1)
# Requirement already satisfied: dill>=0.3 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit>=0.45.2->qiskit-aer) (0.3.6)
# Requirement already satisfied: rustworkx>=0.14.0 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit>=0.45.2->qiskit-aer) (0.14.2)
# Requirement already satisfied: six>=1.5 in c:\users\jakob\anaconda3\lib\site-packages (from python-dateutil>=2.8.0->qiskit>=0.45.2->qiskit-aer) (1.16.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in c:\users\jakob\anaconda3\lib\site-packages (from stevedore>=3.0.0->qiskit>=0.45.2->qiskit-aer) (6.0.0)
# Requirement already satisfied: mpmath>=0.19 in c:\users\jakob\anaconda3\lib\site-packages (from sympy>=1.3->qiskit>=0.45.2->qiskit-aer) (1.2.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: qiskit-transpiler-service in c:\users\jakob\anaconda3\lib\site-packages (0.4.3)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: qiskit~=1.0 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-transpiler-service) (1.0.2)
# Requirement already satisfied: qiskit-qasm3-import~=0.4 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-transpiler-service) (0.4.2)
# Requirement already satisfied: backoff~=2.0 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-transpiler-service) (2.2.1)
# Requirement already satisfied: requests~=2.0 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-transpiler-service) (2.32.2)
# Requirement already satisfied: scipy>=1.5 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit~=1.0->qiskit-transpiler-service) (1.10.0)
# Requirement already satisfied: sympy>=1.3 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit~=1.0->qiskit-transpiler-service) (1.11.1)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit~=1.0->qiskit-transpiler-service) (2.8.2)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit~=1.0->qiskit-transpiler-service) (5.2.0)
# Requirement already satisfied: symengine>=0.11 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit~=1.0->qiskit-transpiler-service) (0.11.0)
# Requirement already satisfied: dill>=0.3 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit~=1.0->qiskit-transpiler-service) (0.3.6)
# Requirement already satisfied: rustworkx>=0.14.0 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit~=1.0->qiskit-transpiler-service) (0.14.2)
# Requirement already satisfied: numpy<2,>=1.17 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit~=1.0->qiskit-transpiler-service) (1.23.5)
# Requirement already satisfied: typing-extensions in c:\users\jakob\anaconda3\lib\site-packages (from qiskit~=1.0->qiskit-transpiler-service) (4.12.1)
# Requirement already satisfied: openqasm3[parser]<0.6,>=0.4 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-qasm3-import~=0.4->qiskit-transpiler-service) (0.5.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jakob\anaconda3\lib\site-packages (from requests~=2.0->qiskit-transpiler-service) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jakob\anaconda3\lib\site-packages (from requests~=2.0->qiskit-transpiler-service) (2024.6.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jakob\anaconda3\lib\site-packages (from requests~=2.0->qiskit-transpiler-service) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jakob\anaconda3\lib\site-packages (from requests~=2.0->qiskit-transpiler-service) (2.2.1)
# Requirement already satisfied: antlr4-python3-runtime<4.14,>=4.7 in c:\users\jakob\anaconda3\lib\site-packages (from openqasm3[parser]<0.6,>=0.4->qiskit-qasm3-import~=0.4->qiskit-transpiler-service) (4.13.1)
# Requirement already satisfied: six>=1.5 in c:\users\jakob\anaconda3\lib\site-packages (from python-dateutil>=2.8.0->qiskit~=1.0->qiskit-transpiler-service) (1.16.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in c:\users\jakob\anaconda3\lib\site-packages (from stevedore>=3.0.0->qiskit~=1.0->qiskit-transpiler-service) (6.0.0)
# Requirement already satisfied: mpmath>=0.19 in c:\users\jakob\anaconda3\lib\site-packages (from sympy>=1.3->qiskit~=1.0->qiskit-transpiler-service) (1.2.1)
# Requirement already satisfied: graphviz in c:\users\jakob\anaconda3\lib\site-packages (0.20.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: circuit-knitting-toolbox in c:\users\jakob\anaconda3\lib\site-packages (0.7.2)
# Requirement already satisfied: qiskit-ibm-runtime>=0.23.0 in c:\users\jakob\anaconda3\lib\site-packages (from circuit-knitting-toolbox) (0.23.0)
# Requirement already satisfied: rustworkx>=0.14.0 in c:\users\jakob\anaconda3\lib\site-packages (from circuit-knitting-toolbox) (0.14.2)
# Requirement already satisfied: numpy>=1.23.0 in c:\users\jakob\anaconda3\lib\site-packages (from circuit-knitting-toolbox) (1.23.5)
# Requirement already satisfied: qiskit<2.0,>=1.0.0 in c:\users\jakob\anaconda3\lib\site-packages (from circuit-knitting-toolbox) (1.0.2)
# Requirement already satisfied: scipy>=1.5.2 in c:\users\jakob\anaconda3\lib\site-packages (from circuit-knitting-toolbox) (1.10.0)
# Requirement already satisfied: qiskit-aer>=0.14.0.1 in c:\users\jakob\anaconda3\lib\site-packages (from circuit-knitting-toolbox) (0.14.2)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit<2.0,>=1.0.0->circuit-knitting-toolbox) (2.8.2)
# Requirement already satisfied: typing-extensions in c:\users\jakob\anaconda3\lib\site-packages (from qiskit<2.0,>=1.0.0->circuit-knitting-toolbox) (4.12.1)
# Requirement already satisfied: symengine>=0.11 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit<2.0,>=1.0.0->circuit-knitting-toolbox) (0.11.0)
# Requirement already satisfied: dill>=0.3 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit<2.0,>=1.0.0->circuit-knitting-toolbox) (0.3.6)
# Requirement already satisfied: sympy>=1.3 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit<2.0,>=1.0.0->circuit-knitting-toolbox) (1.11.1)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit<2.0,>=1.0.0->circuit-knitting-toolbox) (5.2.0)
# Requirement already satisfied: psutil>=5 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-aer>=0.14.0.1->circuit-knitting-toolbox) (5.9.0)
# Requirement already satisfied: ibm-platform-services>=0.22.6 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-ibm-runtime>=0.23.0->circuit-knitting-toolbox) (0.53.7)
# Requirement already satisfied: urllib3>=1.21.1 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-ibm-runtime>=0.23.0->circuit-knitting-toolbox) (2.2.1)
# Requirement already satisfied: requests>=2.19 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-ibm-runtime>=0.23.0->circuit-knitting-toolbox) (2.32.2)
# Requirement already satisfied: requests-ntlm>=1.1.0 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-ibm-runtime>=0.23.0->circuit-knitting-toolbox) (1.2.0)
# Requirement already satisfied: websocket-client>=1.5.1 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-ibm-runtime>=0.23.0->circuit-knitting-toolbox) (1.8.0)
# Requirement already satisfied: pydantic in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-ibm-runtime>=0.23.0->circuit-knitting-toolbox) (2.7.3)
# Requirement already satisfied: ibm-cloud-sdk-core<4.0.0,>=3.19.2 in c:\users\jakob\anaconda3\lib\site-packages (from ibm-platform-services>=0.22.6->qiskit-ibm-runtime>=0.23.0->circuit-knitting-toolbox) (3.20.1)
# Requirement already satisfied: six>=1.5 in c:\users\jakob\anaconda3\lib\site-packages (from python-dateutil>=2.8.0->qiskit<2.0,>=1.0.0->circuit-knitting-toolbox) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jakob\anaconda3\lib\site-packages (from requests>=2.19->qiskit-ibm-runtime>=0.23.0->circuit-knitting-toolbox) (2024.6.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jakob\anaconda3\lib\site-packages (from requests>=2.19->qiskit-ibm-runtime>=0.23.0->circuit-knitting-toolbox) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jakob\anaconda3\lib\site-packages (from requests>=2.19->qiskit-ibm-runtime>=0.23.0->circuit-knitting-toolbox) (2.0.4)
# Requirement already satisfied: pyspnego>=0.1.6 in c:\users\jakob\anaconda3\lib\site-packages (from requests-ntlm>=1.1.0->qiskit-ibm-runtime>=0.23.0->circuit-knitting-toolbox) (0.10.2)
# Requirement already satisfied: cryptography>=1.3 in c:\users\jakob\anaconda3\lib\site-packages (from requests-ntlm>=1.1.0->qiskit-ibm-runtime>=0.23.0->circuit-knitting-toolbox) (39.0.1)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in c:\users\jakob\anaconda3\lib\site-packages (from stevedore>=3.0.0->qiskit<2.0,>=1.0.0->circuit-knitting-toolbox) (6.0.0)
# Requirement already satisfied: mpmath>=0.19 in c:\users\jakob\anaconda3\lib\site-packages (from sympy>=1.3->qiskit<2.0,>=1.0.0->circuit-knitting-toolbox) (1.2.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\jakob\anaconda3\lib\site-packages (from pydantic->qiskit-ibm-runtime>=0.23.0->circuit-knitting-toolbox) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in c:\users\jakob\anaconda3\lib\site-packages (from pydantic->qiskit-ibm-runtime>=0.23.0->circuit-knitting-toolbox) (2.18.4)
# Requirement already satisfied: cffi>=1.12 in c:\users\jakob\anaconda3\lib\site-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime>=0.23.0->circuit-knitting-toolbox) (1.15.1)
# Requirement already satisfied: PyJWT<3.0.0,>=2.8.0 in c:\users\jakob\anaconda3\lib\site-packages (from ibm-cloud-sdk-core<4.0.0,>=3.19.2->ibm-platform-services>=0.22.6->qiskit-ibm-runtime>=0.23.0->circuit-knitting-toolbox) (2.8.0)
# Requirement already satisfied: sspilib>=0.1.0 in c:\users\jakob\anaconda3\lib\site-packages (from pyspnego>=0.1.6->requests-ntlm>=1.1.0->qiskit-ibm-runtime>=0.23.0->circuit-knitting-toolbox) (0.1.0)
# Requirement already satisfied: pycparser in c:\users\jakob\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime>=0.23.0->circuit-knitting-toolbox) (2.21)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: qiskit-serverless in c:\users\jakob\anaconda3\lib\site-packages (0.12.0)
# Requirement already satisfied: opentelemetry.instrumentation.requests>=0.40b0 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-serverless) (0.46b0)
# Requirement already satisfied: s3fs>=2023.6.0 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-serverless) (2024.6.0)
# Requirement already satisfied: ipywidgets>=8.1.2 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-serverless) (8.1.3)
# Requirement already satisfied: opentelemetry-api>=1.18.0 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-serverless) (1.25.0)
# Requirement already satisfied: importlib-metadata>=5.2.0 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-serverless) (7.1.0)
# Requirement already satisfied: qiskit>=1.0.2 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-serverless) (1.0.2)
# Requirement already satisfied: cloudpickle==2.2.1 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-serverless) (2.2.1)
# Requirement already satisfied: tqdm>=4.66.3 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-serverless) (4.66.4)
# Requirement already satisfied: requests>=2.32.2 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-serverless) (2.32.2)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.18.0 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-serverless) (1.25.0)
# Requirement already satisfied: qiskit-ibm-runtime>=0.21.1 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-serverless) (0.23.0)
# Requirement already satisfied: opentelemetry-sdk>=1.18.0 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-serverless) (1.25.0)
# Requirement already satisfied: ray[data,default]<3,>=2.9.3 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-serverless) (2.20.0)
# Requirement already satisfied: qiskit-ibm-provider>=0.10.0 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-serverless) (0.11.0)
# Requirement already satisfied: ipython>=8.10.0 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-serverless) (8.10.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\jakob\anaconda3\lib\site-packages (from importlib-metadata>=5.2.0->qiskit-serverless) (3.11.0)
# Requirement already satisfied: pickleshare in c:\users\jakob\anaconda3\lib\site-packages (from ipython>=8.10.0->qiskit-serverless) (0.7.5)
# Requirement already satisfied: traitlets>=5 in c:\users\jakob\anaconda3\lib\site-packages (from ipython>=8.10.0->qiskit-serverless) (5.7.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\jakob\anaconda3\lib\site-packages (from ipython>=8.10.0->qiskit-serverless) (0.18.1)
# Requirement already satisfied: colorama in c:\users\jakob\anaconda3\lib\site-packages (from ipython>=8.10.0->qiskit-serverless) (0.4.6)
# Requirement already satisfied: stack-data in c:\users\jakob\anaconda3\lib\site-packages (from ipython>=8.10.0->qiskit-serverless) (0.2.0)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.30 in c:\users\jakob\anaconda3\lib\site-packages (from ipython>=8.10.0->qiskit-serverless) (3.0.36)
# Requirement already satisfied: backcall in c:\users\jakob\anaconda3\lib\site-packages (from ipython>=8.10.0->qiskit-serverless) (0.2.0)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\jakob\anaconda3\lib\site-packages (from ipython>=8.10.0->qiskit-serverless) (2.11.2)
# Requirement already satisfied: decorator in c:\users\jakob\anaconda3\lib\site-packages (from ipython>=8.10.0->qiskit-serverless) (5.1.1)
# Requirement already satisfied: matplotlib-inline in c:\users\jakob\anaconda3\lib\site-packages (from ipython>=8.10.0->qiskit-serverless) (0.1.6)
# Requirement already satisfied: widgetsnbextension~=4.0.11 in c:\users\jakob\anaconda3\lib\site-packages (from ipywidgets>=8.1.2->qiskit-serverless) (4.0.11)
# Requirement already satisfied: comm>=0.1.3 in c:\users\jakob\anaconda3\lib\site-packages (from ipywidgets>=8.1.2->qiskit-serverless) (0.2.2)
# Requirement already satisfied: jupyterlab-widgets~=3.0.11 in c:\users\jakob\anaconda3\lib\site-packages (from ipywidgets>=8.1.2->qiskit-serverless) (3.0.11)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\jakob\anaconda3\lib\site-packages (from opentelemetry-api>=1.18.0->qiskit-serverless) (1.2.14)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\jakob\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.18.0->qiskit-serverless) (1.63.1)
# Requirement already satisfied: grpcio<2.0.0,>=1.0.0 in c:\users\jakob\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.18.0->qiskit-serverless) (1.57.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.25.0 in c:\users\jakob\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.18.0->qiskit-serverless) (1.25.0)
# Requirement already satisfied: opentelemetry-proto==1.25.0 in c:\users\jakob\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.18.0->qiskit-serverless) (1.25.0)
# Requirement already satisfied: protobuf<5.0,>=3.19 in c:\users\jakob\anaconda3\lib\site-packages (from opentelemetry-proto==1.25.0->opentelemetry-exporter-otlp-proto-grpc>=1.18.0->qiskit-serverless) (4.24.2)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.46b0 in c:\users\jakob\anaconda3\lib\site-packages (from opentelemetry.instrumentation.requests>=0.40b0->qiskit-serverless) (0.46b0)
# Requirement already satisfied: opentelemetry-util-http==0.46b0 in c:\users\jakob\anaconda3\lib\site-packages (from opentelemetry.instrumentation.requests>=0.40b0->qiskit-serverless) (0.46b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.46b0 in c:\users\jakob\anaconda3\lib\site-packages (from opentelemetry.instrumentation.requests>=0.40b0->qiskit-serverless) (0.46b0)
# Requirement already satisfied: setuptools>=16.0 in c:\users\jakob\anaconda3\lib\site-packages (from opentelemetry-instrumentation==0.46b0->opentelemetry.instrumentation.requests>=0.40b0->qiskit-serverless) (65.6.3)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\jakob\anaconda3\lib\site-packages (from opentelemetry-instrumentation==0.46b0->opentelemetry.instrumentation.requests>=0.40b0->qiskit-serverless) (1.14.1)
# Requirement already satisfied: typing-extensions>=3.7.4 in c:\users\jakob\anaconda3\lib\site-packages (from opentelemetry-sdk>=1.18.0->qiskit-serverless) (4.12.1)
# Requirement already satisfied: sympy>=1.3 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit>=1.0.2->qiskit-serverless) (1.11.1)
# Requirement already satisfied: scipy>=1.5 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit>=1.0.2->qiskit-serverless) (1.10.0)
# Requirement already satisfied: dill>=0.3 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit>=1.0.2->qiskit-serverless) (0.3.6)
# Requirement already satisfied: symengine>=0.11 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit>=1.0.2->qiskit-serverless) (0.11.0)
# Requirement already satisfied: numpy<2,>=1.17 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit>=1.0.2->qiskit-serverless) (1.23.5)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit>=1.0.2->qiskit-serverless) (2.8.2)
# Requirement already satisfied: rustworkx>=0.14.0 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit>=1.0.2->qiskit-serverless) (0.14.2)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit>=1.0.2->qiskit-serverless) (5.2.0)
# Requirement already satisfied: websockets>=10.0 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-ibm-provider>=0.10.0->qiskit-serverless) (12.0)
# Requirement already satisfied: urllib3>=1.21.1 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-ibm-provider>=0.10.0->qiskit-serverless) (2.2.1)
# Requirement already satisfied: requests-ntlm>=1.1.0 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-ibm-provider>=0.10.0->qiskit-serverless) (1.2.0)
# Requirement already satisfied: websocket-client>=1.5.1 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-ibm-provider>=0.10.0->qiskit-serverless) (1.8.0)
# Requirement already satisfied: pydantic in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-ibm-runtime>=0.21.1->qiskit-serverless) (2.7.3)
# Requirement already satisfied: ibm-platform-services>=0.22.6 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-ibm-runtime>=0.21.1->qiskit-serverless) (0.53.7)
# Requirement already satisfied: pyyaml in c:\users\jakob\anaconda3\lib\site-packages (from ray[data,default]<3,>=2.9.3->qiskit-serverless) (6.0)
# Requirement already satisfied: frozenlist in c:\users\jakob\anaconda3\lib\site-packages (from ray[data,default]<3,>=2.9.3->qiskit-serverless) (1.4.1)
# Requirement already satisfied: packaging in c:\users\jakob\anaconda3\lib\site-packages (from ray[data,default]<3,>=2.9.3->qiskit-serverless) (22.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in c:\users\jakob\anaconda3\lib\site-packages (from ray[data,default]<3,>=2.9.3->qiskit-serverless) (1.0.3)
# Requirement already satisfied: jsonschema in c:\users\jakob\anaconda3\lib\site-packages (from ray[data,default]<3,>=2.9.3->qiskit-serverless) (4.17.3)
# Requirement already satisfied: aiosignal in c:\users\jakob\anaconda3\lib\site-packages (from ray[data,default]<3,>=2.9.3->qiskit-serverless) (1.3.1)
# Requirement already satisfied: click>=7.0 in c:\users\jakob\anaconda3\lib\site-packages (from ray[data,default]<3,>=2.9.3->qiskit-serverless) (8.0.4)
# Requirement already satisfied: filelock in c:\users\jakob\anaconda3\lib\site-packages (from ray[data,default]<3,>=2.9.3->qiskit-serverless) (3.14.0)
# Requirement already satisfied: colorful in c:\users\jakob\anaconda3\lib\site-packages (from ray[data,default]<3,>=2.9.3->qiskit-serverless) (0.5.6)
# Requirement already satisfied: aiohttp-cors in c:\users\jakob\anaconda3\lib\site-packages (from ray[data,default]<3,>=2.9.3->qiskit-serverless) (0.7.0)
# Requirement already satisfied: aiohttp>=3.7 in c:\users\jakob\anaconda3\lib\site-packages (from ray[data,default]<3,>=2.9.3->qiskit-serverless) (3.9.5)
# Requirement already satisfied: opencensus in c:\users\jakob\anaconda3\lib\site-packages (from ray[data,default]<3,>=2.9.3->qiskit-serverless) (0.11.4)
# Requirement already satisfied: virtualenv!=20.21.1,>=20.0.24 in c:\users\jakob\anaconda3\lib\site-packages (from ray[data,default]<3,>=2.9.3->qiskit-serverless) (20.26.2)
# Requirement already satisfied: py-spy>=0.2.0 in c:\users\jakob\anaconda3\lib\site-packages (from ray[data,default]<3,>=2.9.3->qiskit-serverless) (0.3.14)
# Requirement already satisfied: smart-open in c:\users\jakob\anaconda3\lib\site-packages (from ray[data,default]<3,>=2.9.3->qiskit-serverless) (5.2.1)
# Requirement already satisfied: prometheus-client>=0.7.1 in c:\users\jakob\anaconda3\lib\site-packages (from ray[data,default]<3,>=2.9.3->qiskit-serverless) (0.14.1)
# Requirement already satisfied: pandas>=1.3 in c:\users\jakob\anaconda3\lib\site-packages (from ray[data,default]<3,>=2.9.3->qiskit-serverless) (1.5.3)
# Requirement already satisfied: fsspec in c:\users\jakob\anaconda3\lib\site-packages (from ray[data,default]<3,>=2.9.3->qiskit-serverless) (2024.6.0)
# Requirement already satisfied: pyarrow>=6.0.1 in c:\users\jakob\anaconda3\lib\site-packages (from ray[data,default]<3,>=2.9.3->qiskit-serverless) (16.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jakob\anaconda3\lib\site-packages (from requests>=2.32.2->qiskit-serverless) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jakob\anaconda3\lib\site-packages (from requests>=2.32.2->qiskit-serverless) (2024.6.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jakob\anaconda3\lib\site-packages (from requests>=2.32.2->qiskit-serverless) (2.0.4)
# Requirement already satisfied: aiobotocore<3.0.0,>=2.5.4 in c:\users\jakob\anaconda3\lib\site-packages (from s3fs>=2023.6.0->qiskit-serverless) (2.13.0)
# Requirement already satisfied: botocore<1.34.107,>=1.34.70 in c:\users\jakob\anaconda3\lib\site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2023.6.0->qiskit-serverless) (1.34.106)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in c:\users\jakob\anaconda3\lib\site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2023.6.0->qiskit-serverless) (0.11.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\jakob\anaconda3\lib\site-packages (from aiohttp>=3.7->ray[data,default]<3,>=2.9.3->qiskit-serverless) (1.9.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\jakob\anaconda3\lib\site-packages (from aiohttp>=3.7->ray[data,default]<3,>=2.9.3->qiskit-serverless) (6.0.5)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\users\jakob\anaconda3\lib\site-packages (from aiohttp>=3.7->ray[data,default]<3,>=2.9.3->qiskit-serverless) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\jakob\anaconda3\lib\site-packages (from aiohttp>=3.7->ray[data,default]<3,>=2.9.3->qiskit-serverless) (22.1.0)
# Requirement already satisfied: ibm-cloud-sdk-core<4.0.0,>=3.19.2 in c:\users\jakob\anaconda3\lib\site-packages (from ibm-platform-services>=0.22.6->qiskit-ibm-runtime>=0.21.1->qiskit-serverless) (3.20.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\jakob\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=8.10.0->qiskit-serverless) (0.8.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jakob\anaconda3\lib\site-packages (from pandas>=1.3->ray[data,default]<3,>=2.9.3->qiskit-serverless) (2022.7)
# Requirement already satisfied: wcwidth in c:\users\jakob\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.30->ipython>=8.10.0->qiskit-serverless) (0.2.5)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\jakob\anaconda3\lib\site-packages (from pydantic->qiskit-ibm-runtime>=0.21.1->qiskit-serverless) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in c:\users\jakob\anaconda3\lib\site-packages (from pydantic->qiskit-ibm-runtime>=0.21.1->qiskit-serverless) (2.18.4)
# Requirement already satisfied: six>=1.5 in c:\users\jakob\anaconda3\lib\site-packages (from python-dateutil>=2.8.0->qiskit>=1.0.2->qiskit-serverless) (1.16.0)
# Requirement already satisfied: pyspnego>=0.1.6 in c:\users\jakob\anaconda3\lib\site-packages (from requests-ntlm>=1.1.0->qiskit-ibm-provider>=0.10.0->qiskit-serverless) (0.10.2)
# Requirement already satisfied: cryptography>=1.3 in c:\users\jakob\anaconda3\lib\site-packages (from requests-ntlm>=1.1.0->qiskit-ibm-provider>=0.10.0->qiskit-serverless) (39.0.1)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in c:\users\jakob\anaconda3\lib\site-packages (from stevedore>=3.0.0->qiskit>=1.0.2->qiskit-serverless) (6.0.0)
# Requirement already satisfied: mpmath>=0.19 in c:\users\jakob\anaconda3\lib\site-packages (from sympy>=1.3->qiskit>=1.0.2->qiskit-serverless) (1.2.1)
# Requirement already satisfied: distlib<1,>=0.3.7 in c:\users\jakob\anaconda3\lib\site-packages (from virtualenv!=20.21.1,>=20.0.24->ray[data,default]<3,>=2.9.3->qiskit-serverless) (0.3.8)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in c:\users\jakob\anaconda3\lib\site-packages (from virtualenv!=20.21.1,>=20.0.24->ray[data,default]<3,>=2.9.3->qiskit-serverless) (4.2.2)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\jakob\anaconda3\lib\site-packages (from jsonschema->ray[data,default]<3,>=2.9.3->qiskit-serverless) (0.18.0)
# Requirement already satisfied: opencensus-context>=0.1.3 in c:\users\jakob\anaconda3\lib\site-packages (from opencensus->ray[data,default]<3,>=2.9.3->qiskit-serverless) (0.1.3)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in c:\users\jakob\anaconda3\lib\site-packages (from opencensus->ray[data,default]<3,>=2.9.3->qiskit-serverless) (2.19.0)
# Requirement already satisfied: pure-eval in c:\users\jakob\anaconda3\lib\site-packages (from stack-data->ipython>=8.10.0->qiskit-serverless) (0.2.2)
# Requirement already satisfied: asttokens in c:\users\jakob\anaconda3\lib\site-packages (from stack-data->ipython>=8.10.0->qiskit-serverless) (2.0.5)
# Requirement already satisfied: executing in c:\users\jakob\anaconda3\lib\site-packages (from stack-data->ipython>=8.10.0->qiskit-serverless) (0.8.3)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\jakob\anaconda3\lib\site-packages (from botocore<1.34.107,>=1.34.70->aiobotocore<3.0.0,>=2.5.4->s3fs>=2023.6.0->qiskit-serverless) (0.10.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\jakob\anaconda3\lib\site-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-provider>=0.10.0->qiskit-serverless) (1.15.1)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in c:\users\jakob\anaconda3\lib\site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[data,default]<3,>=2.9.3->qiskit-serverless) (2.30.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\jakob\anaconda3\lib\site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[data,default]<3,>=2.9.3->qiskit-serverless) (1.23.0)
# Requirement already satisfied: PyJWT<3.0.0,>=2.8.0 in c:\users\jakob\anaconda3\lib\site-packages (from ibm-cloud-sdk-core<4.0.0,>=3.19.2->ibm-platform-services>=0.22.6->qiskit-ibm-runtime>=0.21.1->qiskit-serverless) (2.8.0)
# Requirement already satisfied: sspilib>=0.1.0 in c:\users\jakob\anaconda3\lib\site-packages (from pyspnego>=0.1.6->requests-ntlm>=1.1.0->qiskit-ibm-provider>=0.10.0->qiskit-serverless) (0.1.0)
# Requirement already satisfied: pycparser in c:\users\jakob\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-provider>=0.10.0->qiskit-serverless) (2.21)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\jakob\anaconda3\lib\site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[data,default]<3,>=2.9.3->qiskit-serverless) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\jakob\anaconda3\lib\site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[data,default]<3,>=2.9.3->qiskit-serverless) (5.3.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\jakob\anaconda3\lib\site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[data,default]<3,>=2.9.3->qiskit-serverless) (4.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\jakob\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[data,default]<3,>=2.9.3->qiskit-serverless) (0.4.8)
# Note: you may need to restart the kernel to use updated packages.
# Collecting git+https://github.com/qiskit-community/Quantum-Challenge-Grader.git
#   Cloning https://github.com/qiskit-community/Quantum-Challenge-Grader.git to c:\users\jakob\appdata\local\temp\pip-req-build-kddo0as0
#   Resolved https://github.com/qiskit-community/Quantum-Challenge-Grader.git to commit 96253489893ffda0e53a23ad53ce5e6b992e63d2
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: typeguard in c:\users\jakob\anaconda3\lib\site-packages (from qc-grader==0.18.12) (4.3.0)
# Requirement already satisfied: jsonpickle==3.0.3 in c:\users\jakob\anaconda3\lib\site-packages (from qc-grader==0.18.12) (3.0.3)
# Requirement already satisfied: ipycytoscape in c:\users\jakob\anaconda3\lib\site-packages (from qc-grader==0.18.12) (1.3.3)
# Requirement already satisfied: plotly in c:\users\jakob\anaconda3\lib\site-packages (from qc-grader==0.18.12) (5.9.0)
# Requirement already satisfied: networkx==3.2.1 in c:\users\jakob\anaconda3\lib\site-packages (from qc-grader==0.18.12) (3.2.1)
# Requirement already satisfied: graphviz in c:\users\jakob\anaconda3\lib\site-packages (from qc-grader==0.18.12) (0.20.3)
# Requirement already satisfied: qiskit[visualization]==1.0.2 in c:\users\jakob\anaconda3\lib\site-packages (from qc-grader==0.18.12) (1.0.2)
# Requirement already satisfied: qiskit-ibm-runtime in c:\users\jakob\anaconda3\lib\site-packages (from qc-grader==0.18.12) (0.23.0)
# Requirement already satisfied: qiskit-aer in c:\users\jakob\anaconda3\lib\site-packages (from qc-grader==0.18.12) (0.14.2)
# Requirement already satisfied: qiskit-transpiler-service in c:\users\jakob\anaconda3\lib\site-packages (from qc-grader==0.18.12) (0.4.3)
# Requirement already satisfied: qiskit-serverless==0.12.0 in c:\users\jakob\anaconda3\lib\site-packages (from qc-grader==0.18.12) (0.12.0)
# Requirement already satisfied: circuit-knitting-toolbox in c:\users\jakob\anaconda3\lib\site-packages (from qc-grader==0.18.12) (0.7.2)
# Requirement already satisfied: requests>=2.32.2 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-serverless==0.12.0->qc-grader==0.18.12) (2.32.2)
# Requirement already satisfied: qiskit-ibm-provider>=0.10.0 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-serverless==0.12.0->qc-grader==0.18.12) (0.11.0)
# Requirement already satisfied: opentelemetry.instrumentation.requests>=0.40b0 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-serverless==0.12.0->qc-grader==0.18.12) (0.46b0)
# Requirement already satisfied: cloudpickle==2.2.1 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-serverless==0.12.0->qc-grader==0.18.12) (2.2.1)
# Requirement already satisfied: ray[data,default]<3,>=2.9.3 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-serverless==0.12.0->qc-grader==0.18.12) (2.20.0)
# Requirement already satisfied: opentelemetry-sdk>=1.18.0 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-serverless==0.12.0->qc-grader==0.18.12) (1.25.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.18.0 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-serverless==0.12.0->qc-grader==0.18.12) (1.25.0)
# Requirement already satisfied: s3fs>=2023.6.0 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-serverless==0.12.0->qc-grader==0.18.12) (2024.6.0)
# Requirement already satisfied: ipython>=8.10.0 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-serverless==0.12.0->qc-grader==0.18.12) (8.10.0)
# Requirement already satisfied: importlib-metadata>=5.2.0 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-serverless==0.12.0->qc-grader==0.18.12) (7.1.0)
# Requirement already satisfied: tqdm>=4.66.3 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-serverless==0.12.0->qc-grader==0.18.12) (4.66.4)
# Requirement already satisfied: opentelemetry-api>=1.18.0 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-serverless==0.12.0->qc-grader==0.18.12) (1.25.0)
# Requirement already satisfied: ipywidgets>=8.1.2 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-serverless==0.12.0->qc-grader==0.18.12) (8.1.3)
# Requirement already satisfied: numpy<2,>=1.17 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit[visualization]==1.0.2->qc-grader==0.18.12) (1.23.5)
# Requirement already satisfied: dill>=0.3 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit[visualization]==1.0.2->qc-grader==0.18.12) (0.3.6)
# Requirement already satisfied: typing-extensions in c:\users\jakob\anaconda3\lib\site-packages (from qiskit[visualization]==1.0.2->qc-grader==0.18.12) (4.12.1)
# Requirement already satisfied: rustworkx>=0.14.0 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit[visualization]==1.0.2->qc-grader==0.18.12) (0.14.2)
# Requirement already satisfied: sympy>=1.3 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit[visualization]==1.0.2->qc-grader==0.18.12) (1.11.1)
# Requirement already satisfied: scipy>=1.5 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit[visualization]==1.0.2->qc-grader==0.18.12) (1.10.0)
# Requirement already satisfied: symengine>=0.11 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit[visualization]==1.0.2->qc-grader==0.18.12) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit[visualization]==1.0.2->qc-grader==0.18.12) (2.8.2)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit[visualization]==1.0.2->qc-grader==0.18.12) (5.2.0)
# Requirement already satisfied: matplotlib>=3.3 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit[visualization]==1.0.2->qc-grader==0.18.12) (3.7.0)
# Requirement already satisfied: pylatexenc>=1.4 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit[visualization]==1.0.2->qc-grader==0.18.12) (2.10)
# Requirement already satisfied: pydot in c:\users\jakob\anaconda3\lib\site-packages (from qiskit[visualization]==1.0.2->qc-grader==0.18.12) (2.0.0)
# Requirement already satisfied: seaborn>=0.9.0 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit[visualization]==1.0.2->qc-grader==0.18.12) (0.12.2)
# Requirement already satisfied: Pillow>=4.2.1 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit[visualization]==1.0.2->qc-grader==0.18.12) (9.4.0)
# Requirement already satisfied: pydantic in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-ibm-runtime->qc-grader==0.18.12) (2.7.3)
# Requirement already satisfied: ibm-platform-services>=0.22.6 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-ibm-runtime->qc-grader==0.18.12) (0.53.7)
# Requirement already satisfied: requests-ntlm>=1.1.0 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-ibm-runtime->qc-grader==0.18.12) (1.2.0)
# Requirement already satisfied: websocket-client>=1.5.1 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-ibm-runtime->qc-grader==0.18.12) (1.8.0)
# Requirement already satisfied: urllib3>=1.21.1 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-ibm-runtime->qc-grader==0.18.12) (2.2.1)
# Requirement already satisfied: psutil>=5 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-aer->qc-grader==0.18.12) (5.9.0)
# Requirement already satisfied: spectate>=1.0.0 in c:\users\jakob\anaconda3\lib\site-packages (from ipycytoscape->qc-grader==0.18.12) (1.0.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\jakob\anaconda3\lib\site-packages (from plotly->qc-grader==0.18.12) (8.0.1)
# Requirement already satisfied: backoff~=2.0 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-transpiler-service->qc-grader==0.18.12) (2.2.1)
# Requirement already satisfied: qiskit-qasm3-import~=0.4 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-transpiler-service->qc-grader==0.18.12) (0.4.2)
# Requirement already satisfied: ibm-cloud-sdk-core<4.0.0,>=3.19.2 in c:\users\jakob\anaconda3\lib\site-packages (from ibm-platform-services>=0.22.6->qiskit-ibm-runtime->qc-grader==0.18.12) (3.20.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\jakob\anaconda3\lib\site-packages (from importlib-metadata>=5.2.0->qiskit-serverless==0.12.0->qc-grader==0.18.12) (3.11.0)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.30 in c:\users\jakob\anaconda3\lib\site-packages (from ipython>=8.10.0->qiskit-serverless==0.12.0->qc-grader==0.18.12) (3.0.36)
# Requirement already satisfied: colorama in c:\users\jakob\anaconda3\lib\site-packages (from ipython>=8.10.0->qiskit-serverless==0.12.0->qc-grader==0.18.12) (0.4.6)
# Requirement already satisfied: stack-data in c:\users\jakob\anaconda3\lib\site-packages (from ipython>=8.10.0->qiskit-serverless==0.12.0->qc-grader==0.18.12) (0.2.0)
# Requirement already satisfied: traitlets>=5 in c:\users\jakob\anaconda3\lib\site-packages (from ipython>=8.10.0->qiskit-serverless==0.12.0->qc-grader==0.18.12) (5.7.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\jakob\anaconda3\lib\site-packages (from ipython>=8.10.0->qiskit-serverless==0.12.0->qc-grader==0.18.12) (0.18.1)
# ...
# Requirement already satisfied: comm>=0.1.3 in c:\users\jakob\anaconda3\lib\site-packages (from ipywidgets>=8.1.2->qiskit-serverless==0.12.0->qc-grader==0.18.12) (0.2.2)
# Requirement already satisfied: widgetsnbextension~=4.0.11 in c:\users\jakob\anaconda3\lib\site-packages (from ipywidgets>=8.1.2->qiskit-serverless==0.12.0->qc-grader==0.18.12) (4.0.11)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jakob\anaconda3\lib\site-packages (from matplotlib>=3.3->qiskit[visualization]==1.0.2->qc-grader==0.18.12) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\jakob\anaconda3\lib\site-packages (from matplotlib>=3.3->qiskit[visualization]==1.0.2->qc-grader==0.18.12) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\jakob\anaconda3\lib\site-packages (from matplotlib>=3.3->qiskit[visualization]==1.0.2->qc-grader==0.18.12) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\jakob\anaconda3\lib\site-packages (from matplotlib>=3.3->qiskit[visualization]==1.0.2->qc-grader==0.18.12) (22.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jakob\anaconda3\lib\site-packages (from matplotlib>=3.3->qiskit[visualization]==1.0.2->qc-grader==0.18.12) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\jakob\anaconda3\lib\site-packages (from matplotlib>=3.3->qiskit[visualization]==1.0.2->qc-grader==0.18.12) (0.11.0)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\jakob\anaconda3\lib\site-packages (from opentelemetry-api>=1.18.0->qiskit-serverless==0.12.0->qc-grader==0.18.12) (1.2.14)
# Requirement already satisfied: grpcio<2.0.0,>=1.0.0 in c:\users\jakob\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.18.0->qiskit-serverless==0.12.0->qc-grader==0.18.12) (1.57.0)
# Requirement already satisfied: opentelemetry-proto==1.25.0 in c:\users\jakob\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.18.0->qiskit-serverless==0.12.0->qc-grader==0.18.12) (1.25.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\jakob\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.18.0->qiskit-serverless==0.12.0->qc-grader==0.18.12) (1.63.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.25.0 in c:\users\jakob\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.18.0->qiskit-serverless==0.12.0->qc-grader==0.18.12) (1.25.0)
# Requirement already satisfied: protobuf<5.0,>=3.19 in c:\users\jakob\anaconda3\lib\site-packages (from opentelemetry-proto==1.25.0->opentelemetry-exporter-otlp-proto-grpc>=1.18.0->qiskit-serverless==0.12.0->qc-grader==0.18.12) (4.24.2)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.46b0 in c:\users\jakob\anaconda3\lib\site-packages (from opentelemetry.instrumentation.requests>=0.40b0->qiskit-serverless==0.12.0->qc-grader==0.18.12) (0.46b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.46b0 in c:\users\jakob\anaconda3\lib\site-packages (from opentelemetry.instrumentation.requests>=0.40b0->qiskit-serverless==0.12.0->qc-grader==0.18.12) (0.46b0)
# Requirement already satisfied: opentelemetry-util-http==0.46b0 in c:\users\jakob\anaconda3\lib\site-packages (from opentelemetry.instrumentation.requests>=0.40b0->qiskit-serverless==0.12.0->qc-grader==0.18.12) (0.46b0)
# Requirement already satisfied: setuptools>=16.0 in c:\users\jakob\anaconda3\lib\site-packages (from opentelemetry-instrumentation==0.46b0->opentelemetry.instrumentation.requests>=0.40b0->qiskit-serverless==0.12.0->qc-grader==0.18.12) (65.6.3)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\jakob\anaconda3\lib\site-packages (from opentelemetry-instrumentation==0.46b0->opentelemetry.instrumentation.requests>=0.40b0->qiskit-serverless==0.12.0->qc-grader==0.18.12) (1.14.1)
# Requirement already satisfied: six>=1.5 in c:\users\jakob\anaconda3\lib\site-packages (from python-dateutil>=2.8.0->qiskit[visualization]==1.0.2->qc-grader==0.18.12) (1.16.0)
# Requirement already satisfied: websockets>=10.0 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-ibm-provider>=0.10.0->qiskit-serverless==0.12.0->qc-grader==0.18.12) (12.0)
# Requirement already satisfied: openqasm3[parser]<0.6,>=0.4 in c:\users\jakob\anaconda3\lib\site-packages (from qiskit-qasm3-import~=0.4->qiskit-transpiler-service->qc-grader==0.18.12) (0.5.0)
# Requirement already satisfied: jsonschema in c:\users\jakob\anaconda3\lib\site-packages (from ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc-grader==0.18.12) (4.17.3)
# Requirement already satisfied: pyyaml in c:\users\jakob\anaconda3\lib\site-packages (from ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc-grader==0.18.12) (6.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in c:\users\jakob\anaconda3\lib\site-packages (from ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc-grader==0.18.12) (1.0.3)
# Requirement already satisfied: filelock in c:\users\jakob\anaconda3\lib\site-packages (from ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc-grader==0.18.12) (3.14.0)
# Requirement already satisfied: click>=7.0 in c:\users\jakob\anaconda3\lib\site-packages (from ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc-grader==0.18.12) (8.0.4)
# Requirement already satisfied: aiosignal in c:\users\jakob\anaconda3\lib\site-packages (from ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc-grader==0.18.12) (1.3.1)
# Requirement already satisfied: frozenlist in c:\users\jakob\anaconda3\lib\site-packages (from ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc-grader==0.18.12) (1.4.1)
# Requirement already satisfied: pyarrow>=6.0.1 in c:\users\jakob\anaconda3\lib\site-packages (from ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc-grader==0.18.12) (16.1.0)
# Requirement already satisfied: pandas>=1.3 in c:\users\jakob\anaconda3\lib\site-packages (from ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc-grader==0.18.12) (1.5.3)
# Requirement already satisfied: fsspec in c:\users\jakob\anaconda3\lib\site-packages (from ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc-grader==0.18.12) (2024.6.0)
# Requirement already satisfied: smart-open in c:\users\jakob\anaconda3\lib\site-packages (from ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc-grader==0.18.12) (5.2.1)
# Requirement already satisfied: opencensus in c:\users\jakob\anaconda3\lib\site-packages (from ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc-grader==0.18.12) (0.11.4)
# Requirement already satisfied: prometheus-client>=0.7.1 in c:\users\jakob\anaconda3\lib\site-packages (from ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc-grader==0.18.12) (0.14.1)
# Requirement already satisfied: virtualenv!=20.21.1,>=20.0.24 in c:\users\jakob\anaconda3\lib\site-packages (from ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc-grader==0.18.12) (20.26.2)
# Requirement already satisfied: aiohttp-cors in c:\users\jakob\anaconda3\lib\site-packages (from ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc-grader==0.18.12) (0.7.0)
# Requirement already satisfied: colorful in c:\users\jakob\anaconda3\lib\site-packages (from ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc-grader==0.18.12) (0.5.6)
# Requirement already satisfied: py-spy>=0.2.0 in c:\users\jakob\anaconda3\lib\site-packages (from ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc-grader==0.18.12) (0.3.14)
# Requirement already satisfied: aiohttp>=3.7 in c:\users\jakob\anaconda3\lib\site-packages (from ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc-grader==0.18.12) (3.9.5)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\jakob\anaconda3\lib\site-packages (from pydantic->qiskit-ibm-runtime->qc-grader==0.18.12) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in c:\users\jakob\anaconda3\lib\site-packages (from pydantic->qiskit-ibm-runtime->qc-grader==0.18.12) (2.18.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jakob\anaconda3\lib\site-packages (from requests>=2.32.2->qiskit-serverless==0.12.0->qc-grader==0.18.12) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jakob\anaconda3\lib\site-packages (from requests>=2.32.2->qiskit-serverless==0.12.0->qc-grader==0.18.12) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jakob\anaconda3\lib\site-packages (from requests>=2.32.2->qiskit-serverless==0.12.0->qc-grader==0.18.12) (2024.6.2)
# Requirement already satisfied: pyspnego>=0.1.6 in c:\users\jakob\anaconda3\lib\site-packages (from requests-ntlm>=1.1.0->qiskit-ibm-runtime->qc-grader==0.18.12) (0.10.2)
# Requirement already satisfied: cryptography>=1.3 in c:\users\jakob\anaconda3\lib\site-packages (from requests-ntlm>=1.1.0->qiskit-ibm-runtime->qc-grader==0.18.12) (39.0.1)
# Requirement already satisfied: aiobotocore<3.0.0,>=2.5.4 in c:\users\jakob\anaconda3\lib\site-packages (from s3fs>=2023.6.0->qiskit-serverless==0.12.0->qc-grader==0.18.12) (2.13.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in c:\users\jakob\anaconda3\lib\site-packages (from stevedore>=3.0.0->qiskit[visualization]==1.0.2->qc-grader==0.18.12) (6.0.0)
# Requirement already satisfied: mpmath>=0.19 in c:\users\jakob\anaconda3\lib\site-packages (from sympy>=1.3->qiskit[visualization]==1.0.2->qc-grader==0.18.12) (1.2.1)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in c:\users\jakob\anaconda3\lib\site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2023.6.0->qiskit-serverless==0.12.0->qc-grader==0.18.12) (0.11.0)
# Requirement already satisfied: botocore<1.34.107,>=1.34.70 in c:\users\jakob\anaconda3\lib\site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2023.6.0->qiskit-serverless==0.12.0->qc-grader==0.18.12) (1.34.106)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\jakob\anaconda3\lib\site-packages (from aiohttp>=3.7->ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc-grader==0.18.12) (1.9.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\jakob\anaconda3\lib\site-packages (from aiohttp>=3.7->ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc-grader==0.18.12) (6.0.5)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\users\jakob\anaconda3\lib\site-packages (from aiohttp>=3.7->ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc-grader==0.18.12) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\jakob\anaconda3\lib\site-packages (from aiohttp>=3.7->ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc-grader==0.18.12) (22.1.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\jakob\anaconda3\lib\site-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime->qc-grader==0.18.12) (1.15.1)
# Requirement already satisfied: PyJWT<3.0.0,>=2.8.0 in c:\users\jakob\anaconda3\lib\site-packages (from ibm-cloud-sdk-core<4.0.0,>=3.19.2->ibm-platform-services>=0.22.6->qiskit-ibm-runtime->qc-grader==0.18.12) (2.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\jakob\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=8.10.0->qiskit-serverless==0.12.0->qc-grader==0.18.12) (0.8.3)
# Requirement already satisfied: antlr4-python3-runtime<4.14,>=4.7 in c:\users\jakob\anaconda3\lib\site-packages (from openqasm3[parser]<0.6,>=0.4->qiskit-qasm3-import~=0.4->qiskit-transpiler-service->qc-grader==0.18.12) (4.13.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jakob\anaconda3\lib\site-packages (from pandas>=1.3->ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc-grader==0.18.12) (2022.7)
# Requirement already satisfied: wcwidth in c:\users\jakob\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.30->ipython>=8.10.0->qiskit-serverless==0.12.0->qc-grader==0.18.12) (0.2.5)
# Requirement already satisfied: sspilib>=0.1.0 in c:\users\jakob\anaconda3\lib\site-packages (from pyspnego>=0.1.6->requests-ntlm>=1.1.0->qiskit-ibm-runtime->qc-grader==0.18.12) (0.1.0)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in c:\users\jakob\anaconda3\lib\site-packages (from virtualenv!=20.21.1,>=20.0.24->ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc-grader==0.18.12) (4.2.2)
# Requirement already satisfied: distlib<1,>=0.3.7 in c:\users\jakob\anaconda3\lib\site-packages (from virtualenv!=20.21.1,>=20.0.24->ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc-grader==0.18.12) (0.3.8)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\jakob\anaconda3\lib\site-packages (from jsonschema->ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc-grader==0.18.12) (0.18.0)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in c:\users\jakob\anaconda3\lib\site-packages (from opencensus->ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc-grader==0.18.12) (2.19.0)
# Requirement already satisfied: opencensus-context>=0.1.3 in c:\users\jakob\anaconda3\lib\site-packages (from opencensus->ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc-grader==0.18.12) (0.1.3)
# Requirement already satisfied: executing in c:\users\jakob\anaconda3\lib\site-packages (from stack-data->ipython>=8.10.0->qiskit-serverless==0.12.0->qc-grader==0.18.12) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\jakob\anaconda3\lib\site-packages (from stack-data->ipython>=8.10.0->qiskit-serverless==0.12.0->qc-grader==0.18.12) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\jakob\anaconda3\lib\site-packages (from stack-data->ipython>=8.10.0->qiskit-serverless==0.12.0->qc-grader==0.18.12) (0.2.2)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\jakob\anaconda3\lib\site-packages (from botocore<1.34.107,>=1.34.70->aiobotocore<3.0.0,>=2.5.4->s3fs>=2023.6.0->qiskit-serverless==0.12.0->qc-grader==0.18.12) (0.10.0)
# Requirement already satisfied: pycparser in c:\users\jakob\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime->qc-grader==0.18.12) (2.21)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in c:\users\jakob\anaconda3\lib\site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc-grader==0.18.12) (2.30.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\jakob\anaconda3\lib\site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc-grader==0.18.12) (1.23.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\jakob\anaconda3\lib\site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc-grader==0.18.12) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\jakob\anaconda3\lib\site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc-grader==0.18.12) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\jakob\anaconda3\lib\site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc-grader==0.18.12) (5.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\jakob\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc-grader==0.18.12) (0.4.8)
# Note: you may need to restart the kernel to use updated packages.
#   Running command git clone --filter=blob:none --quiet https://github.com/qiskit-community/Quantum-Challenge-Grader.git 'C:\Users\jakob\AppData\Local\Temp\pip-req-build-kddo0as0'

# %%
### Save API Token, if needed

# %set_env QXToken=ee96018d8124ea8e23f147a3fdc21a2bb23f55ce6b6e372eece81d04cf856d76d60d75100b2264504cd5509218799b9b72b06fa0d5d88d1806cb3af733418492

# Make sure there is no space between the equal sign
# and the beginning of your token
# Out:
# env: QXToken=ee96018d8124ea8e23f147a3fdc21a2bb23f55ce6b6e372eece81d04cf856d76d60d75100b2264504cd5509218799b9b72b06fa0d5d88d1806cb3af733418492

# %%
# qc-grader should be 0.18.11 (or higher)
import qc_grader

qc_grader.__version__
# Out:
# '0.18.12'

# %%
# Imports
import numpy as np
import matplotlib.pyplot as plt

from qiskit import QuantumCircuit
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit.visualization import plot_gate_map
from qiskit.quantum_info import SparsePauliOp

from qiskit_aer import AerSimulator
from qiskit_ibm_runtime import QiskitRuntimeService, SamplerV2 as Sampler
from circuit_knitting.cutting import generate_cutting_experiments, cut_gates

# %%
# Setup the grader

from qc_grader.challenges.iqc_2024 import grade_lab3_ckt_ex1, grade_lab3_ckt_ex2

# %% [markdown]
# # Introduction
# Welcome to Lab 3! Today, we are thrilled to give you an exclusive sneak peek into some of the exciting new features that are being developed for the Qiskit stack. This educational challenge notebook invites you to explore and test some groundbreaking new features. Dive in to explore tools like the Circuit Knitting Toolbox to simplify complex quantum circuits, experience the workflow to setup seamless integration of quantum and classical computing with Qiskit Serverless and have a chance to leverage AI-Powered tools like the Qiskit Code Assistant for code generation and circuit optimization with AI-Powered Transpiler Passes. Dive in and discover how these innovations are set to revolutionize quantum development!

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# Please note, **these features are in beta and release preview**, so you most likely may encounter some bugs. Have fun experimenting and pushing the boundaries of quantum development!
#
# </div>

# %% [markdown]
# # Introducing the Circuit Knitting Toolbox

# %% [markdown]
# In this notebook we will dive into the **Circuit Knitting Toolbox**. This is a tool you can use to simplify complex quantum circuits.
#
# It is true that superconducting processors, like the ones IBM uses in our quantum computers, have limited connectivity. This means if we want to continue to push the boundaries of science, we need to be creative to overcome that limit.
#
# The natural question is, how can we overcome this? One solution is circuit knitting.
#
# As we learned in lab 2, applying gates between distant qubits would require a large swap overhead. Circuit cutting is a technique that reduces the need for swap gates by cutting the gates and/or wires of a large quantum circuit. This decomposes the circuit into smaller ones that can be executed within the constraints of the available quantum hardware. The results of these smaller circuits are then combined to reconstruct the outcome of the original problem.
#
# In short; circuit cutting allows us to run larger circuits on quantum hardware at the cost of additional sampling overhead.

# %% [markdown]
# ## Theory
#
# A quantum channel $\varepsilon$ can be decomposed into a linear combination of several channels $\varepsilon_i$ with coefficients $a_i$. Therefore, a virtual gate also is implemented by a sum over several circuits:
#
# $$\varepsilon(\cdot) = \sum_i a_i \varepsilon(\cdot)$$
# The $a_i$ do not form a valid probability decomposition since some $a_i<0$ cannot sample. We transform to a valid probability distribution via:
#
# $$\gamma = \sum   |a_i| $$
#
# So $\sum\frac{|a_i|}{\gamma}=1$. Therefore, $\frac{|a_i|}{\gamma}$ form a valid probability distribution:
#
# $$\varepsilon(\rho) =\gamma \sum_i \frac{|a_i|}{\gamma} sign(a_i) \varepsilon_i(\cdot)$$
#
# This is Quasi-Probability Decomposition and it allows us to cut gates.
#
# For more information, please refer to the [explanatory material for the circuit cutting module](https://qiskit-extensions.github.io/circuit-knitting-toolbox/circuit_cutting/explanation/index.html).

# %% [markdown]
# ## Cutting a CNOT gate
#
# Now, let's focus on a Bell pair where the qubits are far apart. We will explore how to cut a CNOT gate using the Circuit Knitting Toolbox in this scenario.

# %%
# create a bell pair
bell_state = QuantumCircuit(2)
bell_state.h(0)
bell_state.cx(0,1)
bell_state.draw("mpl")

# %% [markdown]
# Next, we will run this on `ibm_kyoto`! We will use the `ibm_kyoto` device for the rest of this lab.

# %%
## If this is your first time accessing the backend
## remove # and fill your API key, and run the code
service = QiskitRuntimeService(
    channel='ibm_quantum',
    instance='ibm-q/open/main',
    token='ee96018d8124ea8e23f147a3fdc21a2bb23f55ce6b6e372eece81d04cf856d76d60d75100b2264504cd5509218799b9b72b06fa0d5d88d1806cb3af733418492'
)

service = QiskitRuntimeService(channel="ibm_quantum")

# Specify a system to use for transpilation, DO NOT change
backend = service.backend("ibm_kyoto")

# %% [markdown]
# Now, we choose a layout that requires many swaps to execute the gates between qubits 122 and 126, as well as many swaps to return the qubits to their initial positions.

# %%
layout=[122, 126]
qubit_color = []
for i in range(127):
    if i in layout:
        qubit_color.append("#ff0066")
    else:
        qubit_color.append("#6600cc")
plot_gate_map(backend, qubit_color=qubit_color, qubit_size=60, font_size=25, figsize=(8,8))

# %% [markdown]
# We will transpile the Bell pair circuit to get the Instruction Set Architecture (ISA) circuit, which the device can understand and execute.

# %%
# transpile the circuit
pm = generate_preset_pass_manager(backend=backend, optimization_level=1, initial_layout=layout, seed_transpiler=0)
isa_qc = pm.run(bell_state)

# original circuit depth
isa_qc_depth = isa_qc.depth()
print(f"Transpiled circuit depth: ", isa_qc_depth)
isa_qc.draw("mpl", scale=0.6, idle_wires=False, fold=False)
# Out:
# Transpiled circuit depth:  27

# %% [markdown]
# We see that many ancilla qubits are used and the depth of the transpiled circuit is 27! This is the case if we don't use the Qiskit Circuit Knitting Toolbox.

# %% [markdown]
# ## Circuit Knitting
#
# We will replace the distant gates (gates connecting non-local qubits, 122 and 126) with `TwoQubitQPDGate`s by specifying their indices ([QPD](https://qiskit-extensions.github.io/circuit-knitting-toolbox/circuit_cutting/explanation/index.html#circuit-cutting-as-a-quasiprobability-decomposition-qpd) is Quasi-Probability Decomposition which explained in Theory chapter). `cut_gates` will replace the gates in the specified indices with `TwoQubitQPDGate`s and also return a list of `QPDBasis` instances -- one for each gate decomposition. The ``QPDBasis`` object contains information about how to decompose the cut gates into single-qubit operations. For more detail, please refere ["Error mitigation for short-depth quantum circuits"](https://arxiv.org/pdf/1612.02058).
# In the next cell, we will apply `cut_gates` to the bell circuit with specified indices to cut then get the circuit which the CNOT gate is cut.

# %%
# Find the indices of the distant gates
cut_indices = [
    i
    for i, instruction in enumerate(bell_state.data)
    if {bell_state.find_bit(q)[0] for q in instruction.qubits} == {0, 1}
]

# Decompose distant CNOTs into TwoQubitQPDGate instances
qpd_circuit, bases = cut_gates(bell_state, cut_indices)

qpd_circuit.draw("mpl", scale=0.6)

# %% [markdown]
# In the next cell, [`generate_cutting_experiments`](https://qiskit-extensions.github.io/circuit-knitting-toolbox/stubs/circuit_knitting.cutting.generate_cutting_experiments.html#circuit_knitting.cutting.generate_cutting_experiments) accepts a circuit containing `TwoQubitQPDGate` instances and observables as a `PauliList`.
#
# To simulate the expectation value of the full-sized circuit, many sub-experiments are generated from the decomposed gates' joint quasiprobability distribution and then executed on one or more backends. The number of samples taken from the distribution is controlled by `num_samples`, and one combined coefficient is given for each unique sample. For more information on how the coefficients are calculated, refer to the [explanatory material](https://qiskit-extensions.github.io/circuit-knitting-toolbox/circuit_cutting/explanation/index.html).

# %%
observable = SparsePauliOp(["ZI"])

# Generate the sub-experiments and sampling coefficients
sub_experiments, coefficients = generate_cutting_experiments(
    circuits=qpd_circuit, observables=observable.paulis, num_samples=np.inf
)

# %% [markdown]
# Here is an example of an arbitrarily chosen sub-experiment generated from the QPD circuit. Its depth has been reduced significantly from 27 to 7. Many of these probabilistic sub-experiments must be generated and evaluated in order to reconstruct an expectation value of the deeper circuit. For this circuit, we need six sub-experiments to reconstruct it.

# %%
# Transpile the circuit
pm = generate_preset_pass_manager(backend=backend, optimization_level=1, initial_layout=layout, seed_transpiler=0)
isa_qpd_circuit = pm.run(sub_experiments[5])

# depth using circuit cutting
isa_qpd_depth = isa_qpd_circuit.depth()

print(f"Original circuit depth after transpile: ", isa_qc_depth)
print(f"QPD sub-experiment depth after transpile: ", isa_qpd_depth)
print(f"Number of sub-experiments:", len(sub_experiments))
isa_qpd_circuit.draw("mpl", scale=0.6, idle_wires=False, fold=False)
# Out:
# Original circuit depth after transpile:  27
# QPD sub-experiment depth after transpile:  7
# Number of sub-experiments: 6

# %% [markdown]
# The above circuit is the fifth circuit in six sub-experiments. Let's see the depth of all sub-experiments.

# %%
x = np.array([c.depth() for c in pm.run(sub_experiments)])
print(x)
# Out:
# [4 3 3 3 7 7]

# %% [markdown]
# In order to know the expectation value of the original circuit, a number of sub-experiments must be executed. In this case, the six circuits need to be run and reconstructed using subobservables and sampling coefficients. Therefore, with circuit cutting, the depth of each circuit is decreased significantly, but a lot of circuits need to be executed.
# For more information, please refer to the tutorial [Gate Cutting to Reduce Circuit Depth](https://qiskit-extensions.github.io/circuit-knitting-toolbox/circuit_cutting/tutorials/02_gate_cutting_to_reduce_circuit_depth.html).

# %% [markdown]
# ### Toffoli circuit with circuit cutting

# %% [markdown]
# <a id="exercise1"></a>
# <div class="alert alert-block alert-success">
#
# <b> Exercise 1:</b>
#
# Which gate connections should be cut to minimize the circuit depth of the Toffoli gate? Assume that each qubit of the Toffoli gate is located at `[122, 124, 126]` on the `ibm_kyoto` device, and we will cut only one connection. Answer with the gates connecting to cut ({0, 1}, etc.), the depth without using circuit cutting (the original circuit depth), and the average depth with using circuit cutting.
# **Note:** Use `optimization_level=1` and `seed_transpiler=0` as the argument of `generate_preset_pass_manager()`.
# </div>

# %%
toffoli_layout = [122, 124, 126]

toffoli = QuantumCircuit(3)
toffoli.ccx(0, 1, 2)
toffoli.draw("mpl")

# %%
# To know the original circuit depth
### Write your code below here ###
# Transpile the circuit

pm = generate_preset_pass_manager(backend = backend, optimization_level = 1, initial_layout = toffoli_layout, seed_transpiler = 0)
isa_toffoli= pm.run(toffoli)


# Calculate original circuit depth
isa_toffoli_depth = isa_toffoli.depth()

### Don't change any code past this line ###
print(f"Transpiled circuit depth: ", isa_toffoli_depth)
isa_qc.draw("mpl", scale=0.6, idle_wires=False, fold=False)
# Out:
# Transpiled circuit depth:  62

# %% [markdown]
# To cut the circuit, we use the decomposed toffoli circuit not ISA circuit.

# %%
# To know the depth using circuit cutting
toffoli_depth = toffoli.depth()

# Decompose the toffoli circuit
toffoli_ = toffoli.decompose()

### Write your code below here ###
# Find the indices of the distant gates
 # Hint: Expected type: set {int, int}. Docs: https://docs.python.org/3/tutorial/datastructures.html#sets

gates_connecting_to_cut = {0, 2}

cut_indices = [
    i
    for i, instruction in enumerate(toffoli_.data)
    if {toffoli_.find_bit(q)[0] for q in instruction.qubits} == gates_connecting_to_cut
]

# Decompose distant CNOTs into TwoQubitQPDGate instances

qpd_circuit, bases = cut_gates(toffoli_, cut_indices)


### Don't change any code past this line ###

qpd_circuit.draw("mpl", scale=0.6)
# Out:
# [3, 8]

# %%
# set the observables
observable = SparsePauliOp(["ZZZ"])

### Write your code below here ###
# Generate the sub-experiments and sampling coefficients
sub_experiments, coefficients = generate_cutting_experiments(
    circuits=qpd_circuit, observables=observable.paulis, num_samples=np.inf
)

# Transpile the circuit
# Note: Use optimization_level=1 and seed_transpiler=0
# Transpile the circuit
pm = generate_preset_pass_manager(backend = backend, optimization_level=1, initial_layout = toffoli_layout, seed_transpiler=0)
isa_qpd_toffoli = pm.run(sub_experiments[5])


# Depth using circuit cutting
isa_qpd_toffoli_depth =isa_qpd_toffoli.depth()

### Don't change any code past this line ###
print(f"Transpiled circuit depth: ", isa_toffoli_depth)
print(f"QPD sub-experiment depth after transpile: ", isa_qpd_toffoli_depth)
print(f"Number of sub-experiments:", len(sub_experiments))
isa_qpd_circuit.draw("mpl", scale=0.6, idle_wires=False, fold=False)
# Out:
# Transpiled circuit depth:  62
# QPD sub-experiment depth after transpile:  35
# Number of sub-experiments: 36

# %%
### Write your code below here ###
# mean of the depth of all sub-experiments
depth_list = np.array([c.depth() for c in pm.run(sub_experiments)])
isa_qpd_toffoli_depth_mean = np.mean(depth_list)

### Don't change any code past this line ###
print(isa_qpd_toffoli_depth_mean)
# Out:
# 35.333333333333336

# %%
print(gates_connecting_to_cut)
print(isa_toffoli_depth)
depth_list
# Out:
# {0, 2}
# 62
# array([35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 32, 32, 32, 32, 32,
#        32, 32, 32, 32, 32, 32, 32, 39, 39, 39, 39, 39, 39, 39, 39, 39, 39,
#        39, 39])

# %%
# Submit your answer using following code

grade_lab3_ckt_ex1(gates_connecting_to_cut, isa_toffoli_depth, depth_list) 
# Expected result type: set, int, numpy.ndarray
# Out:
# Submitting your answer. Please wait...
# Congratulations! 🎉 Your answer is correct.

# %% [markdown]
# <a id="exercise2"></a>
# <div class="alert alert-block alert-success">
#
# <b> Exercise 2:</b>
#
# Let's think about cutting two connections.
#
# Which two gate connections should be cut to minimize the circuit depth of the Toffoli gate? Assume that each qubit of the Toffoli gate is located at `[122, 124, 126]` on the `ibm_kyoto` device, and we will cut two connections.
#
# **Note:** Use `optimization_level=1` and `seed_transpiler=0` as the argument of `generate_preset_pass_manager()`.
# </div>

# %% [markdown]
# **Note:** It may take more than one minute to run under one condition. So it takes a long time to compare results to find a solution. Because cutting the connection in two places would be expected to reduce the circuit depth, but increase the number of sub-experiments.

# %%
### Write your code below here ###
# Find the indices of the distant gates
gates_connecting_to_cut_1 =  {0,2}# Hint: Expected type: set {int, int}
gates_connecting_to_cut_2 = {1,2}# Hint: Expected type: set {int, int} 

cut_indices = [
    i
    for i, instruction in enumerate(toffoli_.data)
    if ({toffoli_.find_bit(q)[0] for q in instruction.qubits} == gates_connecting_to_cut_1)
    or ({toffoli_.find_bit(q)[0] for q in instruction.qubits} == gates_connecting_to_cut_2)
]

# Decompose distant CNOTs into TwoQubitQPDGate instances

qpd_circuit_2, bases_2 = cut_gates(toffoli_, cut_indices)


### Don't change any code past this line ###
qpd_circuit_2.draw("mpl", scale=0.6)

# %%
# set the observables
observable = SparsePauliOp(["ZZZ"])

### Write your code below here ###
# Generate the sub-experiments and sampling coefficients

sub_experiments_2, coefficients = generate_cutting_experiments(
    circuits=qpd_circuit_2, observables=observable.paulis, num_samples=np.inf
)

# Transpile the circuit
# Note: Use optimization_level=1 and seed_transpiler=0

pm = generate_preset_pass_manager(backend = backend, optimization_level=1, initial_layout = toffoli_layout, seed_transpiler=0)
isa_qpd_circuit_2 = pm.run(sub_experiments[5])



# Depth using circuit cutting
isa_qpd_toffoli_depth_2 =isa_qpd_circuit_2.depth()


### Don't change any code past this line ###
print(f"QPD sub-experiment depth after transpile: ", isa_qpd_toffoli_depth_2)
print(f"Number of sub-experiments:", len(sub_experiments_2))
isa_qpd_circuit_2.draw("mpl", scale=0.6, idle_wires=False, fold=False)
# Out:
# QPD sub-experiment depth after transpile:  35
# Number of sub-experiments: 1296

# %%
# Submit your answer using following code

grade_lab3_ckt_ex2(gates_connecting_to_cut_1, gates_connecting_to_cut_2, sub_experiments_2) 
# Expected result type: set, set, list[QuantumCircuit]
# Out:
# Submitting your answer. Please wait...
# Congratulations! 🎉 Your answer is correct.

# %% [markdown]
# You will find that more than 1000 sub-experiments will be required. So the next cell that calculates the average circuit depth will take a little longer to execute.

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# **IMPORTANT:** Please note, this step may take a few minutes to run.

# %%
### Write your code below here ###
# mean of the depth of all sub-experiments
depth_list_2 = np.array([c.depth() for c in pm.run(sub_experiments_2)])
isa_qpd_toffoli_depth_2_mean =depth_list_2.mean()

### Don't change any code past this line ###
print(isa_qpd_toffoli_depth_2_mean)
# Out:
# 21.246913580246915

# %% [markdown]
# # Visualize results

# %%
# Number of sub-experiments
num_sub_experiments_1_cut = len(sub_experiments)
num_sub_experiments_2_cut = len(sub_experiments_2)

# Data for plotting
categories = ['Before Cutting', 'After 1 Cut', 'After 2 Cuts']
depth_values = [isa_toffoli_depth, isa_qpd_toffoli_depth_mean, isa_qpd_toffoli_depth_2_mean]
num_sub_experiments = [1, num_sub_experiments_1_cut, num_sub_experiments_2_cut]

# Create figure and axis
fig, ax1 = plt.subplots()

# Plot depth values
color = 'tab:blue'
ax1.set_xlabel('Number of Cuts')
ax1.set_ylabel('Circuit Depth', color=color)
bars = ax1.bar(categories, depth_values, color=color, alpha=0.6)
ax1.tick_params(axis='y', labelcolor=color)

# Add value labels on bars
for bar in bars:
    yval = bar.get_height()
    ax1.text(bar.get_x() + bar.get_width() / 2, yval + 1, round(yval, 2), ha='center', color=color, fontsize=10)

# Create a second y-axis to plot the number of subexperiments
ax2 = ax1.twinx()
color = 'tab:green'
ax2.set_ylabel('Number of Sub-experiments', color=color)
ax2.plot(categories, num_sub_experiments, color=color, marker='o')
ax2.tick_params(axis='y', labelcolor=color)

# Add value labels on points
for i, num in enumerate(num_sub_experiments):
    ax2.text(i, num + 0.1, num, ha='center', color=color, fontsize=10)

# Add titles and labels
plt.title('Circuit Knitting Toolbox Results')
fig.tight_layout()  # Adjust layout to make room for both y-axes

# Show plot
plt.show()

# %% [markdown]
# Congratulations on completing the Circuit Knitting Toolbox section! Keep experimenting with these techniques to further refine your skills and unlock new possibilities in quantum computing. Great job!

# %% [markdown]
# # Additional information
#
# **Created by:** Kifumi Numata
#
# **Advised by:** Jennifer Glick, Junye Huang, Vishal Sharathchandra Bajpe
#
# **Version:** 1.1.0
